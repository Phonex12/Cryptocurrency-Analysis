# %% [markdown]
# ### **Exploratory Data Analysis**

# %% [markdown]
# I will Explore various aspects of the data in this EDA

# %% [markdown]
# **Importing Modules**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set(style = 'darkgrid')

# %% [markdown]
# **Importing data and Performing Cleanups**

# %%
df = pd.read_csv('D:\Crypto\Data\crypto_date.csv')
df.drop(columns='Unnamed: 0',inplace = True)
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df = df.dropna()
df['year'] = df['year'].astype('Int64')

# %%
df = df[df['name'] == 'Bitcoin'].copy()

# %%
df_2024 = df[df['year'] == 2024]

# %%
df_2024 = df_2024.reset_index()

# %%
df_2024.drop(columns = 'index',inplace=True)

# %%
df_2024['month_no'] = df_2024['date'].dt.month

# %%
df_2024['month_name'] = pd.to_datetime(df_2024['month_no'],format = '%m').dt.month_name()

# %%
df_2024
# Out:
#     symbol     name       date    price  total_volume  year  month_no  \
# 0      BTC  Bitcoin 2024-01-01  44183.4  1.603857e+09  2024         1
# 1      BTC  Bitcoin 2024-01-02  44943.7  4.397292e+09  2024         1
# 2      BTC  Bitcoin 2024-01-03  42836.1  5.039667e+09  2024         1
# 3      BTC  Bitcoin 2024-01-04  44157.0  3.004884e+09  2024         1
# 4      BTC  Bitcoin 2024-01-05  44156.9  3.005760e+09  2024         1
# ..     ...      ...        ...      ...           ...   ...       ...
# 361    BTC  Bitcoin 2024-12-27  94275.9  8.024765e+09  2024        12
# 362    BTC  Bitcoin 2024-12-28  95284.5  3.141530e+09  2024        12
# 363    BTC  Bitcoin 2024-12-29  93716.3  4.471205e+09  2024        12
# 364    BTC  Bitcoin 2024-12-30  92779.8  1.043123e+10  2024        12
# 365    BTC  Bitcoin 2024-12-31  93557.2  7.002756e+09  2024        12
#
#     month_name
# 0      January
# 1      January
# 2      January
# 3      January
# 4      January
# ..         ...
# ...

# %% [markdown]
# **Plotting the Data**

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data = df_2024,x = 'month_name',y = 'price',marker = 'o')
plt.xticks(rotation = 45)
plt.xlabel('2024')
plt.ylabel('Price USD($)')
plt.title('Change In Price Of Bitcoin In Year 2024')
plt.show()

# %% [markdown]
# This Plot shows the change in the price of Bitcoin in Year 2024
